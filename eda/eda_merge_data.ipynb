# %%
import requests
import sys
import pandas as pd
from bs4 import BeautifulSoup
import os
import csv
sys.path.append("../src")
from data_average import avg_daily_AQI

# %%
def met_data(month, year):
    file_html = open('../data/html_data/{}/{}.html'.format(year,month), 'rb')
    plain_text = file_html.read()

    tempD = []
    finalD = []

    soup = BeautifulSoup(plain_text, "lxml")
    for table in soup.findAll('table', {'class': 'medias mensuales numspan'}):
        for tbody in table:
            for tr in tbody:
                a = tr.get_text()
                tempD.append(a)

    rows = len(tempD) / 15

    for times in range(round(rows)):
        newtempD = []
        for i in range(15):
            newtempD.append(tempD[0])
            tempD.pop(0)
        finalD.append(newtempD)

    length = len(finalD)

    finalD.pop(length - 1)
    finalD.pop(0)

    for a in range(len(finalD)):
        finalD[a].pop(6)
        finalD[a].pop(13)
        finalD[a].pop(12)
        finalD[a].pop(11)
        finalD[a].pop(10)
        finalD[a].pop(9)
        finalD[a].pop(0)

    return finalD

# %%
def data_combine(year, cs):
    for a in pd.read_csv('../data/downloaded-data/data_' + str(year) + '.csv', chunksize=cs):
        df = pd.DataFrame(data=a)
        mylist = df.values.tolist()
    return mylist

# %%
if not os.path.exists("../data/downloaded-data"):
    os.makedirs("../data/downloaded-data")
        
for year in range(2010, 2021):
    final_data = []
    with open('../data/downloaded-data/data_' + str(year) + '.csv', 'w') as csvfile:
        wr = csv.writer(csvfile, dialect='excel')
        wr.writerow(
            ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'])
        
    for month in range(1, 13):
        temp = met_data(month, year)
        final_data = final_data + temp

#     pm = getattr(sys.modules[__name__], 'avg_data_{}'.format(year))()

#     if len(pm) == 364:
#         pm.insert(364, '-')

#     for i in range(len(final_data)-1):
#         # final[i].insert(0, i + 1)
#         final_data[i].insert(8, pm[i])

#     with open('../data/downloaded-data/data_' + str(year) + '.csv', 'a') as csvfile:
#         wr = csv.writer(csvfile, dialect='excel')
#         for row in final_data:
#             flag = 0
#             for elem in row:
#                 if elem == "" or elem == "-":
#                     flag = 1
#             if flag != 1:
#                 wr.writerow(row)

# %%
final_data
# Out:
# [['-2.1', '5.6', '-6.1', '1008.6', '76', '16.1', '17', '29.4'],
#  ['5.4', '8.9', '2.8', '1001.3', '65', '16.1', '23.2', '31.7'],
#  ['3.6', '8.9', '1.1', '1007.6', '80', '16.1', '9.8', '16.5'],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['1.1', '5.6', '-2.2', '1016.5', '62', '16.1', '14.1', '24.1'],
#  ['-4.5', '4.4', '-10', '1024.3', '53', '16.1', '19.8', '33.5'],
#  ['0', '10', '-8.3', '1021.7', '-', '15.9', '22', '35.2'],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['-0.5', '0', '-5', '1025.3', '84', '13.5', '13', '22.2'],
#  ['1.5', '3.9', '-0.6', '1021.1', '85', '13.2', '15.7', '25.9'],
#  ['-0.2', '3.9', '-3.9', '1020.3', '92', '9.8', '8.7', '20.6'],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['-12.8', '-7.2', '-16.7', '1022.7', '71', '15.6', '26.5', '42.4'],
# ...

# %%
# if not os.path.exists("../data/Real-Data"):
#     os.makedirs("../data/Real-Data")
    
# for year in range(2013, 2018):
#     final_data = []
#     with open('../data/Real-Data/real_' + str(year) + '.csv', 'w') as csvfile:
#         wr = csv.writer(csvfile, dialect='excel')
#         wr.writerow(
#             ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'])
#     for month in range(1, 13):
#         temp = met_data(month, year)
#         final_data = final_data + temp

#     pm = getattr(sys.modules[__name__], 'avg_data_{}'.format(year))()

#     if len(pm) == 364:
#         pm.insert(364, '-')

#     for i in range(len(final_data)-1):
#         # final[i].insert(0, i + 1)
#         final_data[i].insert(8, pm[i])

#     with open('../data/Real-Data/real_' + str(year) + '.csv', 'a') as csvfile:
#         wr = csv.writer(csvfile, dialect='excel')
#         for row in final_data:
#             flag = 0
#             for elem in row:
#                 if elem == "" or elem == "-":
#                     flag = 1
#             if flag != 1:
#                 wr.writerow(row)

# data_2013 = data_combine(2013, 600)
# data_2014 = data_combine(2014, 600)
# data_2015 = data_combine(2015, 600)
# data_2016 = data_combine(2016, 600)

# total=data_2013+data_2014+data_2015+data_2016

# with open('../data/Real-Data/Real_Combine.csv', 'w') as csvfile:
#     wr = csv.writer(csvfile, dialect='excel')
#     wr.writerow(
#         ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'])
#     wr.writerows(total)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-15d6a1f75064> in <module>
#      12         final_data = final_data + temp
#      13
# ---> 14     pm = getattr(sys.modules[__name__], 'avg_data_{}'.format(year))()
#      15
#      16     if len(pm) == 364:
#
# AttributeError: module '__main__' has no attribute 'avg_data_2013'
